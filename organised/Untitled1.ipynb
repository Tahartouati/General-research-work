# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data/dayTimeClassDF.csv')

# %%
df.drop(['Unnamed: 0'],axis = 1,inplace = True)

# %%
df.shape
# Out:
# (6662, 95)

# %%
df.head()
# Out:
#       SEQN   intense       light   moderate   sedentary  BMXWT  BMXBMI  \
# 0  21005.0  3.000000   77.166667  26.200000  394.714286  137.6   50.85
# 1  21006.0  0.000000   50.714286   3.200000  427.000000   55.2   20.78
# 2  21007.0  2.666667  219.714286  26.000000  233.142857   47.9   18.43
# 3  21008.0  2.000000   26.571429   8.333333  449.285714   70.0   20.65
# 4  21009.0  1.000000  251.000000  42.000000  186.714286  103.1   31.26
#
#    HUQ050  HUD080    HSQ470  ...  SIAPROXY  SIAINTRP  FIALANG  FIAPROXY  \
# 0     3.0     9.0  2.082021  ...       2.0       2.0      1.0       2.0
# 1     2.0     2.0  2.000000  ...       2.0       2.0      1.0       2.0
# 2     2.0     2.0  2.082021  ...       1.0       2.0      1.0       2.0
# 3     2.0     2.0  2.082021  ...       2.0       2.0      1.0       2.0
# 4     3.0     0.0  2.082021  ...       2.0       2.0      1.0       2.0
#
#    FIAINTRP      WTINT2YR      WTMEC2YR  SDMVPSU  SDMVSTRA        CAT
# ...

# %%
categories = []
for index, row in df.iterrows():
    if row['CAT'] == 'intense':
            categories.append(4)
    elif row['CAT'] == 'moderate':
            categories.append(3)
    elif row['CAT'] == 'light':
            categories.append(2)
    else:
            categories.append(1)

# %%
df['ordCAT'] = categories

# %%
df.shape
# Out:
# (6662, 96)

# %%
corrVec = df.corr().iloc[[94]].drop(['SEQN','intense','moderate','light','sedentary'],axis = 1)

# %%
sortedActiveCorr = corrVec.abs().unstack().sort_values(ascending=False)
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
  print(sortedActiveCorr)
# Out:
# ordCAT    ordCAT    1.000000
# SIAPROXY  ordCAT    0.198762
# RIDAGEYR  ordCAT    0.190827
# RIAGENDR  ordCAT    0.181907
# BMXWT     ordCAT    0.155500
# DMDHHSIZ  ordCAT    0.148980
# BMXBMI    ordCAT    0.145755
# DMDHRAGE  ordCAT    0.127786
# PAD590    ordCAT    0.121459
# DMDEDUC   ordCAT    0.118778
# PAQ520    ordCAT    0.114425
# SIALANG   ordCAT    0.105187
# RIDRETH2  ordCAT    0.099008
# HUQ010    ordCAT    0.096042
# PAD600    ordCAT    0.088820
# FIALANG   ordCAT    0.088021
# PAD320    ordCAT    0.083834
# CDQ006    ordCAT    0.073932
# MCQ160D   ordCAT    0.070448
# CIQG17D   ordCAT    0.069857
# RIDRETH1  ordCAT    0.065263
# PAQ540    ordCAT    0.062204
# DMDCITZN  ordCAT    0.062054
# HSQ500    ordCAT    0.058305
# CIQG14    ordCAT    0.056718
# HSQ590    ordCAT    0.052215
# MCQ180F   ordCAT    0.049574
# RIDEXMON  ordCAT    0.047760
# CIQG17C   ordCAT    0.047679
# HSQ470    ordCAT    0.047516
# HSQ510    ordCAT    0.046669
# MCQ160C   ordCAT    0.046389
# ...
