# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("dataset_V1.csv")

# %%
data.head()
# Out:
#    Unnamed: 0  PFQ061B  PFQ061C  PFQ061H  PAQ670  PAD675  PAD680  PAQ706  \
# 0           0      NaN      NaN      NaN     NaN     NaN     NaN     NaN
# 1           1      NaN      NaN      NaN     NaN     NaN     NaN     NaN
# 2           2      NaN      NaN      NaN     NaN     NaN     NaN     NaN
# 3           3      NaN      NaN      NaN     NaN     NaN     NaN     NaN
# 4           4      NaN      NaN      NaN     NaN     NaN     NaN     NaN
#
#    PAQ710  PAQ715  ...  DPQ060  DPQ070  DPQ080  DPQ090  DPQ100  SLD010H  \
# 0     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN      NaN
# 1     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN      NaN
# 2     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN      NaN
# 3     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN      NaN
# 4     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN      NaN
#
#    CIQD002  CIQD003  CIQD004  CIQD005
# 0      NaN      NaN      NaN      NaN
# ...

# %%
data.shape
# Out:
# (116162, 45)

# %%
column_7 = ['PFQ061B','PFQ061C','PFQ061H','HUQ010','HUQ020','HUQ060','DPQ010','DPQ020','DPQ030','DPQ040','DPQ050','DPQ060','DPQ070','DPQ080','DPQ090','DPQ100','CIQD002','CIQD003','CIQD004','CIQD005']

# %%
column_77 = ['PAQ670','PAQ706','PAQ710','PAQ715','HUQ050','HSQ470','HSQ480','HSQ490','HSQ493','HSQ496','HSQ496']

# %%
column_7777 = ['PAD675','PAD680']

# %%
column_77777 = ['HUD080','MCQ180B','MCQ180C','MCQ180D','MCQ180E','MCQ180F','MCQ180M','MCQ180K']

# %%
data.shape
# Out:
# (116046, 45)

# %%
for column in column_7 :
    data.drop(data.index[data[column] == 7], inplace = True)
    data.drop(data.index[data[column] == 9], inplace = True)
for column in column_77 :
    data.drop(data.index[data[column] == 77], inplace = True)
    data.drop(data.index[data[column] == 99], inplace = True)
for column in column_7777 :
    data.drop(data.index[data[column] == 7777], inplace = True)
    data.drop(data.index[data[column] == 9999], inplace = True)
for column in column_77777 :
    data.drop(data.index[data[column] == 77777], inplace = True)
    data.drop(data.index[data[column] == 99999], inplace = True)

# %%
data.shape
# Out:
# (116046, 45)

# %%
data = data.drop(['Unnamed: 0'], axis=1)

# %%
data.to_csv('dataset_V2.csv')

# %%
data.corr()
# Out:
#           PFQ061B   PFQ061C   PFQ061H    PAQ670    PAD675    PAD680    PAQ706  \
# PFQ061B  1.000000  0.534704  0.232323 -0.117047 -0.033132  0.042532       NaN
# PFQ061C  0.534704  1.000000  0.239789 -0.029403 -0.071221  0.054440       NaN
# PFQ061H  0.232323  0.239789  1.000000 -0.027889 -0.036743  0.054584       NaN
# PAQ670  -0.117047 -0.029403 -0.027889  1.000000 -0.059682 -0.027847       NaN
# PAD675  -0.033132 -0.071221 -0.036743 -0.059682  1.000000  0.008646       NaN
# PAD680   0.042532  0.054440  0.054584 -0.027847  0.008646  1.000000       NaN
# PAQ706        NaN       NaN       NaN       NaN       NaN       NaN  1.000000
# PAQ710   0.144144  0.096536  0.090678  0.025735  0.031256  0.046308 -0.072730
# PAQ715   0.112051  0.062719  0.089386  0.078022  0.007026 -0.014299  0.024145
# HUQ010   0.308195  0.265023  0.212553  0.003094 -0.015100 -0.021357 -0.054885
# HUQ020  -0.069530 -0.040428 -0.055086 -0.013317  0.001120 -0.000953  0.052574
# ...
