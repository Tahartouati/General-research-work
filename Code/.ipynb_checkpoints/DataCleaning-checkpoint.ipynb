# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("merged.csv")

# %%
data.head()
# Out:
#     SEQN PAQ706 PAQ605 PAQ610 PAD615 PAQ620 PAQ625 PAD630 PAQ635 PAQ640  ...  \
# 0  62161             2                    2                    2         ...
# 1  62162      7                                                          ...
# 2  62163             2                    2                    1      6  ...
# 3  62164             1      5     60      2                    2         ...
# 4  62165             2                    2                    1      7  ...
#
#   PFQ061Q PFQ061R PFQ061S PFQ061T PFQ063A PFQ063B PFQ063C PFQ063D PFQ063E  \
# 0       5       5       1       5      28
# 1
# 2
# 3
# 4
#
#   PFQ090
# 0      2
# 1
# 2
# 3      2
# 4
#
# [5 rows x 55 columns]

# %%
datafiltered = data[['SEQN','PFQ061B','PFQ061C','PFQ061H','PFQ054','PFQ020','PAQ665','PAQ670','PAD675','PAD680','PAQ706','PAQ710','PAQ715']]

datafiltered['PFQ061B'].replace(' ',np.nan, inplace=True)
for column in datafiltered:
    datafiltered[column].replace(' ',np.nan, inplace=True)

datafiltered['PFQ061B'].values[12][0]
datafiltered['PFQ061B'] = datafiltered['PFQ061B'].astype(float)
# Out:
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
for column in datafiltered:
    datafiltered[column] = datafiltered[column].astype(float)
# Out:
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
datafiltered.corr()
# Out:
#              SEQN   PFQ061B   PFQ061C   PFQ061H    PFQ054    PFQ020    PAQ665  \
# SEQN     1.000000 -0.007577 -0.008153 -0.017208  0.013593 -0.019075  0.004208
# PFQ061B -0.007577  1.000000  0.520980  0.286552  0.149548       NaN  0.224789
# PFQ061C -0.008153  0.520980  1.000000  0.298036  0.190539       NaN  0.195067
# PFQ061H -0.017208  0.286552  0.298036  1.000000 -0.440766       NaN  0.186922
# PFQ054   0.013593  0.149548  0.190539 -0.440766  1.000000       NaN -0.102985
# PFQ020  -0.019075       NaN       NaN       NaN       NaN  1.000000 -0.054455
# PAQ665   0.004208  0.224789  0.195067  0.186922 -0.102985 -0.054455  1.000000
# PAQ670  -0.014948 -0.117383 -0.025134 -0.028426 -0.020224  0.019112       NaN
# PAD675  -0.005714 -0.032143 -0.072066 -0.036182  0.037229 -0.018072       NaN
# PAD680   0.008518  0.076226  0.085989  0.114201 -0.028876 -0.101944  0.045773
# PAQ706  -0.003496       NaN       NaN       NaN       NaN  0.044276       NaN
# ...

# %%
PFQ061B_corr = datafiltered.corr()['PFQ061B'].drop(['SEQN','PFQ061B'])
max(PFQ061B_corr)
# Out:
# 0.5209799452093363

# %%
testdata = datafiltered[['PFQ061B','PFQ061C']]

# %%
testdata.shape
# Out:
# (9135, 2)

# %%
testdata.dropna().shape
# Out:
# (1943, 2)

# %%
testdata.dropna().corr()
# Out:
#          PFQ061B  PFQ061C
# PFQ061B  1.00000  0.52098
# PFQ061C  0.52098  1.00000
