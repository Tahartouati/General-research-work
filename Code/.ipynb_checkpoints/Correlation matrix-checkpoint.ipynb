# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("all_data.csv")

# %%
data.head()
# Out:
#     SEQN          WTSCI2YR CIAORDER CIQD001 CIQD002 CIQD003 CIQD004 CIQD005  \
# 0  21030
# 1  21043  69650.9756564349        1       2
# 2  21052  170898.870733588        1       2
# 3  21085  69867.4539578865        1       2
# 4  21115  50786.0283533147        1       1       4
#
#   CIQD006 CIQD007  ... PFQ061T PFQ063A PFQ063B PFQ063C PFQ063D PFQ063E PFQ090  \
# 0                  ...
# 1                  ...
# 2                  ...
# 3                  ...
# 4                  ...
#
#   SLD010H SLQ050 SLQ060
# 0
# 1
# 2
# 3
# 4
#
# [5 rows x 631 columns]

# %%
data.shape
# Out:
# (116162, 631)

# %%
arr = ['SEQN','PFQ061B','PFQ061C','PFQ061H','PFQ054','PFQ020','PAQ665','PAQ670','PAD675','PAD680','PAQ706','PAQ710','PAQ715','HUQ010','HUQ020','HUQ030','HUQ040','HUQ050','HUQ060','HUQ071','HUD080','HUQ090','HSQ470','HSQ480','HSQ490','HSQ493','HSQ496','MCQ160a','MCQ180a','MCQ195','MCQ160n','MCQ180n','MCQ160b','MCQ180b','MCQ160c','MCQ180c','MCQ160d','MCQ180d','MCQ160e','MCQ180e','MCQ160f','MCQ180f','MCQ160m','MCQ170m','MCQ180m','MCQ160k','MCQ170k','MCQ180k','MCQ300a','MCQ365a','MCQ365b','MCQ365c','MCQ365d','MCQ370a','MCQ370b','MCQ370c','MCQ370d','DPQ010','DPQ020','DPQ030','DPQ040','DPQ050','DPQ060','DPQ070','DPQ080','DPQ090','DPQ100','CDQ009A','CDQ009C','CDQ009G','CDQ010','SLD010H','SLQ050','SLQ060','FSD010','HHfdsec','ADfdsec','CHfdsec','CIQD002','CIQD003','CIQD004','CIQD005','CIQDPD','CIQDPHI','CIQDPHJ','CIQDPK','CIQDPN','CIQG14','CIQGPHI','CIQGPHJ','CIQGPD','CIQGPN']

# %%
newARR = []
for element in arr:
    newARR.append(element.upper())

# %%
newARR.remove('HHFDSEC')
newARR.remove('CHFDSEC')
newARR.remove('ADFDSEC')
newARR.remove('FSD010')
datafiltered = data[newARR]

# %%
datafiltered.shape
# Out:
# (116162, 88)

# %%
# replacing empty values with nan:
for column in datafiltered:
    datafiltered[column].replace(' ',np.nan, inplace=True)

# %%
# converting the values from string to float, so we can compute the correlation matrix:
for column in datafiltered:
    datafiltered[column] = datafiltered[column].astype(float)
# Out:
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
datafiltered.to_csv('dataset_V1.csv')

# %%
datafiltered = pd.read_csv("dataset_V1.csv")

# %%
datafiltered = datafiltered.drop(['PFQ054','PFQ020','PAQ665','HUQ030','HUQ040','HUQ071','HUQ090','MCQ160A','MCQ195','MCQ160N','MCQ160B','MCQ160C','MCQ160C','MCQ160E','MCQ160F','MCQ160M','MCQ170M','MCQ160K','MCQ170K','MCQ300A','MCQ365A','MCQ365B','MCQ365C','MCQ365D','MCQ370A','MCQ370B','MCQ370D','MCQ370C','CDQ009A','CDQ009C','CDQ009G','CDQ010','SLQ050','SLQ060','CIQDPD','CIQDPHI','CIQDPHJ','CIQDPK','CIQDPN','CIQG14','CIQGPHI','CIQGPHJ','CIQGPD','CIQGPN'], axis=1)

# %%
datafiltered = datafiltered.drop(['Unnamed: 0', 'SEQN'], axis=1)

# %%
datafiltered.to_csv('dataset_V1.csv')

# %%
# Out:
#         PFQ061B  PFQ061C  PFQ061H  PAQ670  PAD675  PAD680  PAQ706  PAQ710  \
# 0           NaN      NaN      NaN     NaN     NaN     NaN     NaN     NaN
# 1           NaN      NaN      NaN     NaN     NaN     NaN     NaN     NaN
# 2           NaN      NaN      NaN     NaN     NaN     NaN     NaN     NaN
# 3           NaN      NaN      NaN     NaN     NaN     NaN     NaN     NaN
# 4           NaN      NaN      NaN     NaN     NaN     NaN     NaN     NaN
# 5           NaN      NaN      NaN     NaN     NaN     NaN     NaN     NaN
# 6           NaN      NaN      NaN     NaN     NaN     NaN     NaN     NaN
# 7           NaN      NaN      NaN     NaN     NaN     NaN     NaN     NaN
# 8           NaN      NaN      NaN     NaN     NaN     NaN     NaN     NaN
# 9           NaN      NaN      NaN     NaN     NaN     NaN     NaN     NaN
# 10          NaN      NaN      NaN     NaN     NaN     NaN     NaN     NaN
# 11          NaN      NaN      NaN     NaN     NaN     NaN     NaN     NaN
# ...

# %%
correlationMatrix = datafiltered.corr()

# %%
correlationMatrix = correlationMatrix.drop(['SEQN','PFQ061B','PFQ061H','PFQ054','PFQ020','PFQ061C'],axis=1)

# %%
correlationMatrixY = correlationMatrix.iloc[[1,2,3,4,5]]
correlationMatrixY

# %%
correlationMatrixY.idxmax(axis=1)

# %%
# inserting correlation values for each Y variable into a dictionary:
PFQ061B_correlation = correlationMatrixY.iloc[2]
PFQ061B_max_correlation = max(PFQ061B_correlation)
PFQ061B_max_correlation
