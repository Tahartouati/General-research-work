# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("dataset_V4.csv")

# %%
data.drop(['Unnamed: 0.1','Unnamed: 0'],axis=1,inplace=True)

# %%
data.head()
# Out:
#    PFQ061B  PFQ061C  PFQ061H  PAQ670  PAD675  PAD680  PAQ706  PAQ710  PAQ715  \
# 0      NaN      NaN      NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1      NaN      NaN      NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2      NaN      NaN      NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 3      NaN      NaN      NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4      NaN      NaN      NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#    HUQ010  ...  DPQ060  DPQ070  DPQ080  DPQ090  DPQ100  SLD010H  CIQD002  \
# 0     NaN  ...     NaN     NaN     NaN     NaN     NaN      NaN      NaN
# 1     NaN  ...     NaN     NaN     NaN     NaN     NaN      NaN      NaN
# 2     NaN  ...     NaN     NaN     NaN     NaN     NaN      NaN      NaN
# 3     NaN  ...     NaN     NaN     NaN     NaN     NaN      NaN      NaN
# 4     NaN  ...     NaN     NaN     NaN     NaN     NaN      NaN      4.0
#
#    CIQD003  CIQD004  CIQD005
# 0      NaN      NaN      NaN
# ...

# %%
column_7 = ['PFQ061B','PFQ061C','PFQ061H','HUQ010','HUQ020','HUQ060','DPQ010','DPQ020','DPQ030','DPQ040','DPQ050','DPQ060','DPQ070','DPQ080','DPQ090','DPQ100','CIQD002','CIQD003','CIQD004','CIQD005']

# %%
column_77 = ['PAQ670','PAQ706','PAQ710','PAQ715','HUQ050','HSQ470','HSQ480','HSQ490','HSQ493','HSQ496','HSQ496']

# %%
column_7777 = ['PAD675','PAD680']

# %%
column_77777 = ['HUD080','MCQ180A','MCQ180B','MCQ180C','MCQ180D','MCQ180E','MCQ180F','MCQ180M','MCQ180K']

# %%
data.shape
# Out:
# (116162, 44)

# %%
for column in column_7 :
    data[column].replace(7,np.nan, inplace=True)
    data[column].replace(9,np.nan, inplace=True)
    data[column].replace(7.0,np.nan, inplace=True)
    data[column].replace(9.0,np.nan, inplace=True)
for column in column_77 :
    data[column].replace(77.0,np.nan, inplace=True)
    data[column].replace(99.0,np.nan, inplace=True)
    data[column].replace(77,np.nan, inplace=True)
    data[column].replace(99,np.nan, inplace=True)
for column in column_7777 :
    data[column].replace(7777,np.nan, inplace=True)
    data[column].replace(9999,np.nan, inplace=True)
    data[column].replace(7777.0,np.nan, inplace=True)
    data[column].replace(9999.0,np.nan, inplace=True)
for column in column_77777 :
    data[column].replace(77777,np.nan, inplace=True)
    data[column].replace(99999,np.nan, inplace=True)
    data[column].replace(77777.0,np.nan, inplace=True)
    data[column].replace(99999.0,np.nan, inplace=True)

# %%
data['MCQ180A'].mean()
# Out:
# 50.46078431372549

# %%
data.to_csv('dataset_V4.csv')

# %%
data.corr()
# Out:
#           PFQ061B   PFQ061C   PFQ061H    PAQ670    PAD675    PAD680    PAQ706  \
# PFQ061B  1.000000  0.528541  0.247670 -0.117383 -0.032143  0.092893       NaN
# PFQ061C  0.528541  1.000000  0.244539 -0.025134 -0.072066  0.061170       NaN
# PFQ061H  0.247670  0.244539  1.000000 -0.028426 -0.036182  0.169259       NaN
# PAQ670  -0.117383 -0.025134 -0.028426  1.000000 -0.059850 -0.064892       NaN
# PAD675  -0.032143 -0.072066 -0.036182 -0.059850  1.000000 -0.052626       NaN
# PAD680   0.092893  0.061170  0.169259 -0.064892 -0.052626  1.000000       NaN
# PAQ706        NaN       NaN       NaN       NaN       NaN       NaN  1.000000
# PAQ710   0.124604  0.094169  0.079530 -0.019887  0.035566  0.175334 -0.077392
# PAQ715  -0.052112 -0.053789 -0.081175 -0.075136  0.010156  0.217428 -0.100431
# HUQ010   0.310907  0.268038  0.224732  0.002252 -0.015552 -0.062238 -0.056161
# HUQ020  -0.064784 -0.035282 -0.055985 -0.013740 -0.000092  0.004572  0.052108
# ...
